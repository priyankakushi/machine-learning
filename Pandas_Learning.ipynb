# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["Soni", "Amit", "Rahul", "Priyanka"],
    "Marks":[34,40,56,80],
    "City": ["Bihar", "Delhi", "Patna", "Pune"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name  Marks   City
# 0      Soni     34  Bihar
# 1      Amit     40  Delhi
# 2     Rahul     56  Patna
# 3  Priyanka     80   Pune

# %%
df.to_csv("friends.csv")

# %%
df.head()
# Out:
#        name  Marks   City
# 0      Soni     34  Bihar
# 1      Amit     40  Delhi
# 2     Rahul     56  Patna
# 3  Priyanka     80   Pune

# %%
df.head(2)
# Out:
#    name  Marks   City
# 0  Soni     34  Bihar
# 1  Amit     40  Delhi

# %%
df.tail(2)
# Out:
#        name  Marks   City
# 2     Rahul     56  Patna
# 3  Priyanka     80   Pune

# %%
df.describe()
# Out:
#           Marks
# count   4.00000
# mean   52.50000
# std    20.55075
# min    34.00000
# 25%    38.50000
# 50%    48.00000
# 75%    62.00000
# max    80.00000

# %%
herry = pd.read_csv("herry1.csv")

# %%
herry
# Out:
#    Train No  Speed   City
# 0      1234     34  Bihar
# 1      4356     40  Delhi
# 2      3424     56  Patna
# 3      8761     80   Pune

# %%
herry.Speed
# Out:
# 0    34
# 1    40
# 2    56
# 3    80
# Name: Speed, dtype: int64

# %%
herry["Speed"]
# Out:
# 0    34
# 1    40
# 2    56
# 3    80
# Name: Speed, dtype: int64

# %%
herry["Speed"][0]
# Out:
# 34

# %%
herry["City"][1]
# Out:
# 'Delhi'

# %%
herry
# Out:
#    Train No  Speed   City
# 0      1234     34  Bihar
# 1      4356     40  Delhi
# 2      3424     56  Patna
# 3      8761     80   Pune

# %%
herry.to_csv("herry.csv")

# %%
herry.index = ["first", "second", "third", "fourth"]
herry
# Out:
#         Train No  Speed   City
# first       1234     34  Bihar
# second      4356     40  Delhi
# third       3424     56  Patna
# fourth      8761     80   Pune

# %%
ser = pd.Series(np.random.rand(34))
ser
# Out:
# 0     0.491406
# 1     0.538475
# 2     0.067098
# 3     0.606208
# 4     0.197717
# 5     0.831898
# 6     0.920951
# 7     0.104599
# 8     0.450376
# 9     0.974514
# 10    0.479584
# 11    0.157112
# 12    0.822622
# 13    0.927060
# 14    0.329778
# 15    0.578060
# 16    0.962650
# 17    0.397079
# 18    0.620998
# 19    0.278758
# 20    0.324780
# 21    0.085100
# 22    0.678617
# 23    0.949054
# 24    0.267054
# 25    0.359831
# 26    0.045518
# 27    0.715411
# 28    0.372690
# 29    0.438328
# 30    0.527908
# 31    0.292955
# 32    0.607294
# 33    0.418722
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.030870  0.663570  0.072570  0.301594  0.754138
# 1    0.981527  0.517794  0.600669  0.309002  0.582202
# 2    0.214764  0.541709  0.042857  0.754402  0.766658
# 3    0.267381  0.610599  0.999654  0.236331  0.226915
# 4    0.763613  0.632273  0.594661  0.184594  0.414823
# ..        ...       ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.863519  0.539253
# 330  0.211355  0.645246  0.671049  0.777139  0.655165
# 331  0.874576  0.343608  0.087129  0.396808  0.091338
# 332  0.974557  0.093675  0.125893  0.124632  0.364427
# 333  0.649034  0.819291  0.849234  0.098018  0.967832
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.030870  0.663570  0.072570  0.301594  0.754138
# 1  0.981527  0.517794  0.600669  0.309002  0.582202
# 2  0.214764  0.541709  0.042857  0.754402  0.766658
# 3  0.267381  0.610599  0.999654  0.236331  0.226915
# 4  0.763613  0.632273  0.594661  0.184594  0.414823

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.loc[[1,2],["C","D"]]
# Out:
#           C         D
# 1  0.600669  0.309002
# 2  0.042857  0.754402

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.981527  0.517794  0.600669  0.309002  0.582202
# 2  0.214764  0.541709  0.042857  0.754402  0.766658

# %%
newdf.loc[(newdf["A"]<0.3)] & (newdf[])
# Out:
#               A         B         C         D         E
# 2      0.214764  0.541709  0.042857  0.754402  0.766658
# 3      0.267381  0.610599  0.999654  0.236331  0.226915
# 8    0.00158582  0.680416  0.275294  0.078238  0.704178
# 10    0.0928079  0.321843  0.262391  0.566722  0.958335
# 17      0.24655  0.876976  0.248030  0.706456  0.733748
# ..          ...       ...       ...       ...       ...
# 318    0.167127  0.846919  0.444839  0.816340  0.677440
# 327   0.0634171  0.256961  0.969087  0.342302  0.416713
# 328     0.13035  0.725861  0.670580  0.117703  0.278074
# 329    0.162357  0.865264  0.205447  0.863519  0.539253
# 330    0.211355  0.645246  0.671049  0.777139  0.655165
#
# [90 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0      2345  0.663570  0.072570  0.301594  0.754138
# 1  0.981527  0.517794  0.600669  0.309002  0.582202

# %%
newdf.iloc[0,4]
# Out:
# 0.7541379012638706

# %%
newdf.iloc[1,3]
# Out:
# 0.3090015310258448

# %%
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         C
# 0  0.663570  0.072570
# 1  0.517794  0.600669

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.981527  0.517794  0.600669  0.309002  0.582202
# 2    0.214764  0.541709  0.042857  0.754402  0.766658
# 3    0.267381  0.610599  0.999654  0.236331  0.226915
# 4    0.763613  0.632273  0.594661  0.184594  0.414823
# 5    0.514813  0.298186  0.748151  0.335615  0.181266
# ..        ...       ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.863519  0.539253
# 330  0.211355  0.645246  0.671049  0.777139  0.655165
# 331  0.874576  0.343608  0.087129  0.396808  0.091338
# 332  0.974557  0.093675  0.125893  0.124632  0.364427
# 333  0.649034  0.819291  0.849234  0.098018  0.967832
#
# [333 rows x 5 columns]

# %%
newdf
# Out:
#             A         B         C         D         E
# 0        2345  0.663570  0.072570  0.301594  0.754138
# 1    0.981527  0.517794  0.600669  0.309002  0.582202
# 2    0.214764  0.541709  0.042857  0.754402  0.766658
# 3    0.267381  0.610599  0.999654  0.236331  0.226915
# 4    0.763613  0.632273  0.594661  0.184594  0.414823
# ..        ...       ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.863519  0.539253
# 330  0.211355  0.645246  0.671049  0.777139  0.655165
# 331  0.874576  0.343608  0.087129  0.396808  0.091338
# 332  0.974557  0.093675  0.125893  0.124632  0.364427
# 333  0.649034  0.819291  0.849234  0.098018  0.967832
#
# [334 rows x 5 columns]

# %%
newdf.drop([2])
# Out:
#             A         B         C         D         E
# 0        2345  0.663570  0.072570  0.301594  0.754138
# 1    0.981527  0.517794  0.600669  0.309002  0.582202
# 3    0.267381  0.610599  0.999654  0.236331  0.226915
# 4    0.763613  0.632273  0.594661  0.184594  0.414823
# 5    0.514813  0.298186  0.748151  0.335615  0.181266
# ..        ...       ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.863519  0.539253
# 330  0.211355  0.645246  0.671049  0.777139  0.655165
# 331  0.874576  0.343608  0.087129  0.396808  0.091338
# 332  0.974557  0.093675  0.125893  0.124632  0.364427
# 333  0.649034  0.819291  0.849234  0.098018  0.967832
#
# [333 rows x 5 columns]

# %%
newdf.head
# Out:
# <bound method NDFrame.head of             A         B         C         D         E
# 0        2345  0.663570  0.072570  0.301594  0.754138
# 1    0.981527  0.517794  0.600669  0.309002  0.582202
# 2    0.214764  0.541709  0.042857  0.754402  0.766658
# 3    0.267381  0.610599  0.999654  0.236331  0.226915
# 4    0.763613  0.632273  0.594661  0.184594  0.414823
# ..        ...       ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.863519  0.539253
# 330  0.211355  0.645246  0.671049  0.777139  0.655165
# 331  0.874576  0.343608  0.087129  0.396808  0.091338
# 332  0.974557  0.093675  0.125893  0.124632  0.364427
# 333  0.649034  0.819291  0.849234  0.098018  0.967832
#
# [334 rows x 5 columns]>

# %%
newdf.drop(["A"], axis=1)
# Out:
#             B         C         D         E
# 0    0.663570  0.072570  0.301594  0.754138
# 1    0.517794  0.600669  0.309002  0.582202
# 2    0.541709  0.042857  0.754402  0.766658
# 3    0.610599  0.999654  0.236331  0.226915
# 4    0.632273  0.594661  0.184594  0.414823
# ..        ...       ...       ...       ...
# 329  0.865264  0.205447  0.863519  0.539253
# 330  0.645246  0.671049  0.777139  0.655165
# 331  0.343608  0.087129  0.396808  0.091338
# 332  0.093675  0.125893  0.124632  0.364427
# 333  0.819291  0.849234  0.098018  0.967832
#
# [334 rows x 4 columns]

# %%
#tamporari column delete
newdf.drop(["D"], axis = 1)
# Out:
#             A         B         C         E
# 0        2345  0.663570  0.072570  0.754138
# 1    0.981527  0.517794  0.600669  0.582202
# 2    0.214764  0.541709  0.042857  0.766658
# 3    0.267381  0.610599  0.999654  0.226915
# 4    0.763613  0.632273  0.594661  0.414823
# ..        ...       ...       ...       ...
# 329  0.162357  0.865264  0.205447  0.539253
# 330  0.211355  0.645246  0.671049  0.655165
# 331  0.874576  0.343608  0.087129  0.091338
# 332  0.974557  0.093675  0.125893  0.364427
# 333  0.649034  0.819291  0.849234  0.967832
#
# [334 rows x 4 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0      2345  0.663570  0.072570  0.301594  0.754138
# 1  0.981527  0.517794  0.600669  0.309002  0.582202
# 2  0.214764  0.541709  0.042857  0.754402  0.766658
# 3  0.267381  0.610599  0.999654  0.236331  0.226915
# 4  0.763613  0.632273  0.594661  0.184594  0.414823

# %%
#orignal column delete
newdf.drop(["D","E"], axis = 1, inplace=True)

# %%
newdf.head()
# Out:
#           A         B         C
# 0      2345  0.663570  0.072570
# 1  0.981527  0.517794  0.600669
# 2  0.214764  0.541709  0.042857
# 3  0.267381  0.610599  0.999654
# 4  0.763613  0.632273  0.594661

# %%
#Rows delete
newdf.drop([0,1], axis=0, inplace=True)
newdf
# Out:
#               A         B         C
# 2      0.214764  0.541709  0.042857
# 5      0.514813  0.298186  0.748151
# 6      0.811767  0.182789  0.836634
# 7      0.961106  0.331560  0.620668
# 8    0.00158582  0.680416  0.275294
# ..          ...       ...       ...
# 329    0.162357  0.865264  0.205447
# 330    0.211355  0.645246  0.671049
# 331    0.874576  0.343608  0.087129
# 332    0.974557  0.093675  0.125893
# 333    0.649034  0.819291  0.849234
#
# [330 rows x 3 columns]

# %%
newdf.reset_index(drop=True, inplace=True)
newdf.head(3)
# Out:
#           A         B         C
# 0  0.214764  0.541709  0.042857
# 1  0.514813  0.298186  0.748151
# 2  0.811767  0.182789  0.836634

# %%
newdf["B"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# Name: B, Length: 330, dtype: bool

# %%
newdf["B"] = None
newdf.head()
# Out:
#             A     B         C
# 0    0.214764  None  0.042857
# 1    0.514813  None  0.748151
# 2    0.811767  None  0.836634
# 3    0.961106  None  0.620668
# 4  0.00158582  None  0.275294

# %%
newdf["B"].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 325    True
# 326    True
# 327    True
# 328    True
# 329    True
# Name: B, Length: 330, dtype: bool

# %%
newdf.loc[:, "B"]=59
newdf.head()
# Out:
#             A   B         C
# 0    0.214764  59  0.042857
# 1    0.514813  59  0.748151
# 2    0.811767  59  0.836634
# 3    0.961106  59  0.620668
# 4  0.00158582  59  0.275294

# %%
df = df = pd.DataFrame({"Name":["Pooja", "Radha", "Ram"],
                       "toy": [np.nan, np.nan, np.nan],
                       "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                                pd.NaT]})

# %%
df
# Out:
#     Name  toy       born
# 0  Pooja  NaN        NaT
# 1  Radha  NaN 1940-04-25
# 2    Ram  NaN        NaT

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Name, toy, born]
# Index: []

# %%
df.dropna(how="all", axis=1)
# Out:
#     Name       born
# 0  Pooja        NaT
# 1  Radha 1940-04-25
# 2    Ram        NaT

# %%
 df.drop_duplicates(subset=["Name"], keep = "first")
# Out:
#     Name  toy       born
# 0  Pooja  NaN        NaT
# 1  Radha  NaN 1940-04-25
# 2    Ram  NaN        NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# Name    3 non-null object
# toy     0 non-null float64
# born    1 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 200.0+ bytes

# %%
df["toy"].value_counts(dropna=False)
# Out:
# NaN    3
# Name: toy, dtype: int64

# %%
df
# Out:
#     Name  toy       born
# 0  Pooja  NaN        NaT
# 1  Radha  NaN 1940-04-25
# 2    Ram  NaN        NaT

# %%
df.notnull()
# Out:
#    Name    toy   born
# 0  True  False  False
# 1  True  False   True
# 2  True  False  False

# %%
df.isnull()
# Out:
#     Name   toy   born
# 0  False  True   True
# 1  False  True  False
# 2  False  True   True

# %%
#create a dataframe which contains only integers with 3 rows and 2 columns
#run following dataframe method on them 
df.decribe()
df.mean()
df.midean()
df.std()
df.corr()
df.count()
df.min()
df.max()
# Out:
# '#create a dataframe which contains only integers with 3 rows and 2 columns\n#run following dataframe method on them \ndf.decribe()\ndf.mean()\ndf.midean()\ndf.std()\ndf.corr()\ndf.count()\ndf.min()\ndf.max()'

# %%
dict = {
    "Name":["priyanka", "amit", "rahul"],
    "Marks":[35, 56, 80]
}

# %%
df = pd.DataFrame(dict)
df
# Out:
#        Name  Marks
# 0  priyanka     35
# 1      amit     56
# 2     rahul     80

# %%
df.describe()
# Out:
#           Marks
# count   3.00000
# mean   57.00000
# std    22.51666
# min    35.00000
# 25%    45.50000
# 50%    56.00000
# 75%    68.00000
# max    80.00000

# %%
df.mean()
# Out:
# Marks    57.0
# dtype: float64

# %%
df.median()
# Out:
# Marks    56.0
# dtype: float64

# %%
df.std()
# Out:
# Marks    22.51666
# dtype: float64

# %%
df.corr()
# Out:
#        Marks
# Marks    1.0

# %%
df.min()
# Out:
# Name     amit
# Marks      35
# dtype: object

# %%
df.max()
# Out:
# Name     rahul
# Marks       80
# dtype: object
