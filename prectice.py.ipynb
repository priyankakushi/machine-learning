# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [4,5,1])
plt.title("info")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()  #line chart

# %%
plt.plot([1,2,7], [4, 8,6])
plt.title("info")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %%
plt.plot([3,4,9], [1,6,8])
plt.title("info")
plt.xlabel("x Axis")
plt.ylabel("y Axis")
plt.show()

# %%
plt.plot([1,2,4], [1,3,5])
plt.title("info")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
plt.plot([2,4,9], [1,2,7])
plt.title("info")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.show()

# %% [markdown]
# # Double Line Chart

# %%
import matplotlib.style as st
st.use("ggplot")
x = [5,8,10]
y = [12, 6, 6]

x2 = [6,9,11]
y2 = [6,15,7]
plt.plot(x,y, "g", label="line one", linewidth = 5)
plt.plot(x2,y2, "c", label="line two", linewidth = 5)
plt.title("Epic Info")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()
plt.grid(True, color = "k")
plt.show()

# %%
st.use("ggplot")
x = [1,4,8]
y = [5,7,9]
x1=[6,2,10]
y1=[3,7,8]
plt.plot(x,y, "g", label="line one", linewidth=5)
plt.plot(x1,y2, "c", label="line two", linewidth=5)
plt.title("efic info")
plt.xlabel("X axis")
plt.ylabel("y axis")
plt.legend
plt.grid(True, color="k")
plt.show()

# %%
st.use("ggplot")
x = [1,2,5], [1,4,3]
y = [1,2,8], [2,4,6]

x1 = [2,3,7], [1,2,3]
y1 = [1,2,7], [3,5,7]
plt.plot(x,y, "g", label = "line one", linewidth=5)
plt.plot(x1,y1, "c", label = "line two", linewidth=5)
plt.title("efic info")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.legend
plt.grid(True, color="r")
plt.show()

# %% [markdown]
# # Bar Chart

# %%
plt.bar([1,3,5,7,9], [5,2,7,8,9], label="Example one")
plt.bar([2,4,6,8,10], [8,6,2,5,6], label="Example two", color= "g")
plt.legend()
plt.xlabel("Bar Number")
plt.ylabel("Bar Hight")
plt.title("info")
plt.show()

# %% [markdown]
# # Name Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
names1880 = pd.read_csv("/Users/amitkumarsahu/Desktop/babynames/yob1880.txt",names=['name', 'sex', 'Name_Number'])
names1880
# Out:
#            name sex  Name_Number
# 0          Mary   F         7065
# 1          Anna   F         2604
# 2          Emma   F         2003
# 3     Elizabeth   F         1939
# 4        Minnie   F         1746
# ...         ...  ..          ...
# 1995     Woodie   M            5
# 1996     Worthy   M            5
# 1997     Wright   M            5
# 1998       York   M            5
# 1999  Zachariah   M            5
#
# [2000 rows x 3 columns]

# %%
names1880["year"]=1880
names1880.head()
# Out:
#         name sex  Name_Number  year
# 0       Mary   F         7065  1880
# 1       Anna   F         2604  1880
# 2       Emma   F         2003  1880
# 3  Elizabeth   F         1939  1880
# 4     Minnie   F         1746  1880

# %%
names1880["Name_Number"].groupby(names1880["sex"]).sum()
# Out:
# sex
# F     90993
# M    110493
# Name: Name_Number, dtype: int64

# %%
names1880.Name_Number.groupby(names1880.sex).sum()
# Out:
# sex
# F     90993
# M    110493
# Name: Name_Number, dtype: int64

# %%
names1880.groupby("sex").Name_Number.sum() # groupby command
# Out:
# sex
# F     90993
# M    110493
# Name: Name_Number, dtype: int64

# %%
years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'Name_Number']

for i in years:
    
    path = '/Users/amitkumarsahu/Desktop/babynames/yob%d.txt'% i
    frame = pd.read_csv(path, names=columns)

    frame['year'] =i
    pieces.append(frame)

# Concatenate everything into a single DataFrame
names = pd.concat(pieces, ignore_index=True) ## Concat command?

# %%
names
# Out:
#               name sex  Name_Number  year
# 0             Mary   F         7065  1880
# 1             Anna   F         2604  1880
# 2             Emma   F         2003  1880
# 3        Elizabeth   F         1939  1880
# 4           Minnie   F         1746  1880
# ...            ...  ..          ...   ...
# 1690779    Zymaire   M            5  2010
# 1690780     Zyonne   M            5  2010
# 1690781  Zyquarius   M            5  2010
# 1690782      Zyran   M            5  2010
# 1690783      Zzyzx   M            5  2010
#
# [1690784 rows x 4 columns]

# %%
total_births = names.pivot_table('Name_Number', index ='year',columns='sex', aggfunc=sum)
total_births.head()  ##  pivot_table ?
# Out:
# sex        F       M
# year
# 1880   90993  110493
# 1881   91955  100748
# 1882  107851  113687
# 1883  112322  104632
# 1884  129021  114445

# %%
total_births.plot(title='Total births by sex and year')##
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-1ce3a6f14e0d> in <module>
# ----> 1 total_births.plot(title='Total births by sex and year')##
#
# NameError: name 'total_births' is not defined

# %%
def add_prop(x):
    x['prop'] = (x.Name_Number)*100/ x.Name_Number.sum()
    return x

names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  Name_Number  year      prop
# 0             Mary   F         7065  1880  7.764334
# 1             Anna   F         2604  1880  2.861759
# 2             Emma   F         2003  1880  2.201268
# 3        Elizabeth   F         1939  1880  2.130933
# 4           Minnie   F         1746  1880  1.918829
# ...            ...  ..          ...   ...       ...
# 1690779    Zymaire   M            5  2010  0.000263
# 1690780     Zyonne   M            5  2010  0.000263
# 1690781  Zyquarius   M            5  2010  0.000263
# 1690782      Zyran   M            5  2010  0.000263
# 1690783      Zzyzx   M            5  2010  0.000263
#
# [1690784 rows x 5 columns]

# %%
names.groupby(["year", "sex"]).prop.sum()
# Out:
# year  sex
# 1880  F      100.0
#       M      100.0
# 1881  F      100.0
#       M      100.0
# 1882  F      100.0
#              ...
# 2008  M      100.0
# 2009  F      100.0
#       M      100.0
# 2010  F      100.0
#       M      100.0
# Name: prop, Length: 262, dtype: float64

# %%
def get_top1000(group):
    return group.sort_values(by='Name_Number', ascending=False)[:1000]

grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)
# Drop the group index, not needed
top1000.reset_index(inplace=True, drop=True)

# %%
top1000
# Out:
#              name sex  Name_Number  year      prop
# 0            Mary   F         7065  1880  7.764334
# 1            Anna   F         2604  1880  2.861759
# 2            Emma   F         2003  1880  2.201268
# 3       Elizabeth   F         1939  1880  2.130933
# 4          Minnie   F         1746  1880  1.918829
# ...           ...  ..          ...   ...       ...
# 261872     Camilo   M          194  2010  0.010219
# 261873     Destin   M          194  2010  0.010219
# 261874     Jaquan   M          194  2010  0.010219
# 261875     Jaydan   M          194  2010  0.010219
# 261876     Maxton   M          193  2010  0.010167
#
# [261877 rows x 5 columns]

# %%
boys = top1000[top1000['sex'] == 'M'] ## or boys = top1000[top1000.sex == 'M']
girls = top1000[top1000['sex'] == 'F']

# %%
boys
# Out:
#            name sex  Name_Number  year      prop
# 942        John   M         9655  1880  8.738110
# 943     William   M         9533  1880  8.627696
# 944       James   M         5927  1880  5.364141
# 945     Charles   M         5348  1880  4.840126
# 946      George   M         5126  1880  4.639208
# ...         ...  ..          ...   ...       ...
# 261872   Camilo   M          194  2010  0.010219
# 261873   Destin   M          194  2010  0.010219
# 261874   Jaquan   M          194  2010  0.010219
# 261875   Jaydan   M          194  2010  0.010219
# 261876   Maxton   M          193  2010  0.010167
#
# [130997 rows x 5 columns]

# %%
girls
# Out:
#              name sex  Name_Number  year      prop
# 0            Mary   F         7065  1880  7.764334
# 1            Anna   F         2604  1880  2.861759
# 2            Emma   F         2003  1880  2.201268
# 3       Elizabeth   F         1939  1880  2.130933
# 4          Minnie   F         1746  1880  1.918829
# ...           ...  ..          ...   ...       ...
# 260872    Violeta   F          250  2010  0.014213
# 260873     Leilah   F          250  2010  0.014213
# 260874    Alaysia   F          250  2010  0.014213
# 260875      Dania   F          249  2010  0.014156
# 260876     Yadira   F          249  2010  0.014156
#
# [130880 rows x 5 columns]

# %%
total_births = top1000.pivot_table('Name_Number', index='year',
                                   columns='name',
                                   aggfunc=sum)
total_births
# Out:
# name   Aaden  Aaliyah  Aarav   Aaron  Aarush  Ab  Abagail  Abb  Abbey  Abbie  \
# year
# 1880     NaN      NaN    NaN   102.0     NaN NaN      NaN  NaN    NaN   71.0
# 1881     NaN      NaN    NaN    94.0     NaN NaN      NaN  NaN    NaN   81.0
# 1882     NaN      NaN    NaN    85.0     NaN NaN      NaN  NaN    NaN   80.0
# 1883     NaN      NaN    NaN   105.0     NaN NaN      NaN  NaN    NaN   79.0
# 1884     NaN      NaN    NaN    97.0     NaN NaN      NaN  NaN    NaN   98.0
# ...      ...      ...    ...     ...     ...  ..      ...  ...    ...    ...
# 2006     NaN   3737.0    NaN  8279.0     NaN NaN    297.0  NaN  404.0  440.0
# 2007     NaN   3941.0    NaN  8914.0     NaN NaN    313.0  NaN  349.0  468.0
# 2008   955.0   4028.0  219.0  8511.0     NaN NaN    317.0  NaN  344.0  400.0
# 2009  1265.0   4352.0  270.0  7936.0     NaN NaN    296.0  NaN  307.0  369.0
# 2010   448.0   4628.0  438.0  7374.0   226.0 NaN    277.0  NaN  295.0  324.0
#
# name  ...   Zoa     Zoe    Zoey   Zoie  Zola  Zollie  Zona  Zora  Zula   Zuri
# year  ...
# 1880  ...   8.0    23.0     NaN    NaN   7.0     NaN   8.0  28.0  27.0    NaN
# 1881  ...   NaN    22.0     NaN    NaN  10.0     NaN   9.0  21.0  27.0    NaN
# 1882  ...   8.0    25.0     NaN    NaN   9.0     NaN  17.0  32.0  21.0    NaN
# 1883  ...   NaN    23.0     NaN    NaN  10.0     NaN  11.0  35.0  25.0    NaN
# 1884  ...  13.0    31.0     NaN    NaN  14.0     6.0   8.0  58.0  27.0    NaN
# ...   ...   ...     ...     ...    ...   ...     ...   ...   ...   ...    ...
# 2006  ...   NaN  5145.0  2839.0  530.0   NaN     NaN   NaN   NaN   NaN    NaN
# 2007  ...   NaN  4925.0  3028.0  526.0   NaN     NaN   NaN   NaN   NaN    NaN
# 2008  ...   NaN  4764.0  3438.0  492.0   NaN     NaN   NaN   NaN   NaN    NaN
# 2009  ...   NaN  5120.0  3981.0  496.0   NaN     NaN   NaN   NaN   NaN    NaN
# 2010  ...   NaN  6200.0  5164.0  504.0   NaN     NaN   NaN   NaN   NaN  258.0
#
# [131 rows x 6868 columns]

# %%
total_births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 131 entries, 1880 to 2010
# Columns: 6868 entries, Aaden to Zuri
# dtypes: float64(6868)
# memory usage: 6.9 MB

# %%
subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]
subset.plot(subplots=True, figsize=(12, 10), grid=True,title="Number of births per year") 
## Subplot ?
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11dfad9d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11fa50b90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x122491750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x11fb62890>],
#       dtype=object)

# %%
plt.figure()
table = top1000.pivot_table('prop', index='year',
                            columns='sex', aggfunc=sum)
table.plot(title='Sum of table1000.prop by year and sex',
           yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 30),alpha=0.5)

# %%
table
# Out:
# sex            F           M
# year
# 1880  100.000000   99.737540
# 1881  100.000000  100.000000
# 1882   99.870191   99.564594
# 1883   99.759620   99.856640
# 1884   99.315615   99.453886
# ...          ...         ...
# 2006   75.315323   86.036813
# 2007   74.595908   85.515904
# 2008   74.093261   85.000320
# 2009   73.728950   84.525573
# 2010   73.678035   84.315644
#
# [131 rows x 2 columns]
